# %% [markdown]
# #Antes de empezar
#
# Antes de empezar deberemos configurar nuestras cuentas de Google y de GitHub.
#
# ##Creación cuenta de GitHub
# Para poder realizar las prácticas de la asignatura, vamos a necesitar una de cuenta de GitHub. GitHub es un herramienta que nos permite tener un control de versiones sobre los programas que desarrollemos. Es una herramienta muy útil para equipos de desarrollo ya que permite trabajar simultáneamente sobre el mismo proyecto. Además, nos permite guardar nuestros programas en la nube lo que hace que podamos acceder a ellos desde cualquier dispositivo con conexión a internet.
#
# Para crear nuestra cuenta en GitHub, primero deberemos accecer a la página web, https://github.com/ . Una vez estemos en la página principal, pulsaremos en el boton de "*sign up*". Aunque ya tengas una cuenta, te recomendamos que crees una con los datos que te facilita la universidad, con la cuasi, correo y contraseña (deberá tener como mínimo 15 caracteres o al menos 8 incluyendo una minúscula y un número). Una vez introducidos los datos, tienes que elegir el plan, que será el plan gratuito. Por último, tendrás que verificar la cuenta utilizando el código que te hayan envíado al correo usado para crear la cuenta.
#
# Tienes la información accesible también en el siguiente vídeo: https://www.youtube.com/watch?v=BQPkH95VzQk
#
#
# ##Usar GitHub con Google Colaboratory
#
# Primero, deberemos iniciar sesión en nuestra cuenta de GitHub creada en el paso anterior. Luego, tendremos que aceptar la tarea que tenemos incluida en el aula virtual. Al aceptar la tarea, nos aparecerá en la propia página un enlace al que deberemos acceder. En esta página de GitHub ya podremos ver el repositorio de la práctica. Los archivos que veremos son de formato ipynb que es el formato de los cuadernos de Jupyter que utiliza Google Colab para poder trabajar. Si accedemos a los cuardernos desde GitHub vemos que te permite visualizar la  información  que tiene el cuaderno sin problema pero no nos deja modificarlo. Para eso, tendremos que acceder a https://colab.research.google.com/ donde tendremos que conectarnos con nuestra cuenta de Google. Ahora, podemos abrir los cuadernos de GitHub que tenemos. Para ello iremos a la pestaña de GitHub e introducir el nombre de usuario y marcar que nos aparezcan los repositorios privados. Al pinchar en el cuaderno que queramos, se nos abre automáticamente. La ventaja de usar estas herramientas es que podremos usarlas desde cualquier ordenador con acceso a internet sin necesidad de instalar ningún programa extra.
#
# Tienes la información accesible también en el siguiente vídeo: https://www.youtube.com/watch?v=jbnsu2MbBOY

# %% [markdown]
# #Práctica 01
# #Introducción al entorno de programación
# El objetivo de esta práctica es el aprendizaje del entorno de programación Google Colab, que permite la escritura y ejecución de programas escritos en el lenguaje Python.
# Un entorno de programación, también reconocido por su acrónimo en inglés IDE (Integrated Development Environment), es un programa que proporciona todas las herramientas que el programador necesita para desarrollar sus programas. Estas básicamente son:
# * Un editor de texto para escribir el código fuente.
# * Un compilador para obtener el código ejecutable.
# * Un entorno para la ejecución segura de los programas creados.
# * Un depurador para corregir los errores de ejecución.
#
# En este caso, nosotros trabajamos con Python y con Google Colab y hay algunas de estas características que no tenemos disponibles como son el compilador (Python es un lenguaje interpretado por lo que no necesita ser compilado) y el depurador (para [depurar](https://colab.research.google.com/github/QuantEcon/lecture-python-programming.notebooks/blob/master/debugging.ipynb) con Google Colab hace falta utilizar una librería específica).

# %% [markdown]
# ##Google Colab, un entorno de programación
# El entorno de programación con el que vamos a trabajar en las prácticas de la asignatura es Google Colab. Se trata de un IDE gratuito y es fácil de usar. Google Colab es un IDE (Integrated Development Environment) que incluye herramientas para la creación de programas en Python. Además, No necesita de instalación ya que es un servicio en la nube desde el que podemos acceder desde cualquier sitio con conexión a internet.
# Para trabajar con Google Colab tendremos que acceder a su página (https://colab.google/), donde también puedes encontrar un manual y acceso a un cuaderno con los primeros pasos a seguir con la herramienta.
# Aprendiendo a trabajar con programas
#
# ##Pasos en la creación de un programa:
# Edición. En esta tarea se escribe el programa (código) en un determinado lenguaje de programación (en nuestro caso Python). Se llama programa fuente, y una vez guardado tendrá extensión py. Nosotros creamos un cuaderno de Jupyter que tiene extensión ipynb.
#
# Ejecución. Puesta en funcionamiento del programa. En esta fase también pueden aparecer errores por mal funcionamiento del programa, por un mal diseño del mismo.
#
# Depuración. Búsqueda y corrección de errores de ejecución. La mayoría de los entornos de programación disponen de herramientas de ayuda para la depuración. Típicamente ofrecen la posibilidad de ejecutar paso a paso el programa y consultar los valores que van tomando las variables (seguimiento de la traza de ejecución para detectar dónde y por qué se producen los errores).
#
# Para los lenguajes que se compilan hay que añadir un paso extra entre el paso 1 y 2 en el que se realiza la traducción del código del programa a un archivo ejecutable para el ordenador.
#
# ###Creación de un proyecto y edición del código
# Para poder ejecutar nuestros programas en Google Colab, es necesario crear un nuevo cuaderno. En esta asignatura crearemos proyectos de consola, que son aquellos que se ejecutan en una ventana de símbolo del sistema.
# ![Captura de pantalla 2024-07-30 102617.png](data:image/png;base64,...)

# %% [markdown]
# Para crear un nuevo cuaderno accedemos a Archivo/ Cuaderno nuevo en Drive en la barra de menús, o bien dando en el enlace New Notebook desde la página principal de [Google Colab](https://colab.google/). Al crear un nuevo cuaderno, automáticamente el lenguaje de programación utilizado es Python y se abre el entorno de desarrollo en blanco.
#
# ###Edita un programa
# Google Colab presenta el aspecto de una aplicación web. El panel principal es el de edición, donde se escribe el código fuente. A la izquierda tenemos varios botones, el primero el índice, sirve para organizar el cuaderno en diferentes secciones, como un documento de texto. El segundo es para buscar y reemplazar dentro del cuaderno. El tercer botón nos muestra todas las variables que hemos usado dentro del cuaderno y el tipo que tienen. El siguiente botón nos ayuda a crear “secretos” (Configura tu código almacenando variables de entorno, rutas de archivos o claves. Los valores que se almacenan aquí son privados y solo puedes verlos tú en los cuadernos que selecciones.). Y por último el botón de archivos, en este caso nos muestra el árbol de los archivos creados y/o descargados en el cuaderno.
#
# ![Captura de pantalla 2024-07-30 103358.png](data:image/png;base64,...)

# %% [markdown]
# En el cuaderno, tenemos el código fuente de nuestro primer programa. Aparece una propuesta para tu programa, úsalo como plantilla, pero modifícalo como te indicamos a continuación. Este será el código de nuestro primer ejemplo:

# %%
base=5
altura=7
area = base * altura
print("El área es: "+ str(area))
print(f"El área es: {area}") # Otra forma de imprimir por pantalla los resultados
# Out:
# El área es: 35
# El área es: 35

# %% [markdown]
# ###Guarda el programa
# Selecciona en el menú archivo la opción Archivo/Guardar. Recuerda guardarlo en GitHub para que se mantengan los cambios realizados en el repositorio, para realizarlo tienes que seleccionar en el menú archivo la opción Archivo/Guardar una copia en GitHub .
#
# Una buena costumbre que debes adquirir es guardar a menudo el programa.
# ###Corrige los errores
# Durante el ciclo de desarrollo de un programa pueden aparecer errores, los hay de dos tipos:
#
# *   Errores de Ejecución: Se producen durante la ejecución del programa. Se detectan porque el funcionamiento del programa no es el deseado, debido a un fallo en la implementación o incluso en el diseño del programa (errores de diseño). Son los más difíciles de corregir y habitualmente hay que recurrir a la ayuda del IDE, al llamado depurador (o debbuger).
# *   Errores de Compilación: Pueden deberse a fallos durante la escritura del programa (errores léxicos) o a faltas cometidas contra la sintaxis del lenguaje (errores sintácticos). Son los más fáciles de detectar y corregir, ya que el compilador los detecta y sugiere cuál puede ser la causa del error. Después de corregir los errores es necesario volver a compilar el programa. En nuestro caso, Python no utiliza compilador por lo que no tendremos este tipo de errores.
#
# ###Ejecuta el programa
# Para ejecutar el programa, tenemos varias opciones. Pulsar el botón "*play*" situado a la izquierda de la celda del cuaderno seleccionada. También se puede ejecutar dentro de la pestaña Entorno de ejecución del menú. Esa pestaña del menú nos permite ejecutar tanto la celda seleccionada como varias celdas, dependiendo de las celdas que se quieran ejecutar. Por último, también se puede ejecutar la celda activa pulsando la combinación de botones control + Enter o Mayús + Enter (salta a la siguiente celda de ejecución).
#
# El programa se ejecuta y justo debajo de la celda que se está ejecutando se muestra la salida del programa.
# ![Captura de pantalla 2024-07-30 104942.png](data:image/png;base64,...)

# %% [markdown]
# ###Algunas características de Google Colab y sus cuadernos
# Como podemos apreciar, los cuadernos son una herramienta de programación muy útil pero además podemos añadir texto entre las celdas que contienen código. Esta característica es realmente útil ya que podemos aportar explicaciones del código entre las celdas. Para crear una celda de texto, simplemente tendrás que pulsar en el botón Texto que aparece en la parte superior de la ventana o en el que aparece al situarte en la parte central superior o inferior de las celdas del cuaderno.
#
# El formato con el que se puede escribir dentro de esas celdas es Markdown. Este formato de texto nos permite escribir añadiendo cierto formato al texto como niveles de título, tamaño de letra, negrita, etc.
#
# ##Sesión de Prácticas
# ###Primer programa
# Con este ejercicio aprenderás a:
# *   Recuperar un programa previamente creado y guardado.
# *   Corregir los errores de un programa
#
# También repasarás como:
# *   Ejecutarlo

# %%
# FECHA:
# AUTOR: profesores de Informática
# DESCRIPCIÓN:
# Calcula el valor de un polinomio de tercer grado para un valor concreto de la incógnita
# x. Los coeficientes del polinomio son introducidos por teclado, así como el valor de la
# incógnita. El resultado se presenta por pantalla.
# ENTRADAS: los coeficientes del polinomio (variables a,b,c,d)
# el valor de la incógnita (variable x)
# SALIDAS: el resultado de la expresión ax^3+bx^2+cx+d (almacenado en la variable p)

# Entrada de datos
print( "Introducir los valores de: ")
print("a = ? ")
a=int(input())
print("b = ? ")
b=int(input())
print("c = ? ")
c=int(input())
print("d = ? ")
d=int(input())
print("x = ? ")
x=int(input())
# Proceso
solucion = (a*x*x*x) + (b*x*x) + (c*x) + d;

# Salida
print("La solución es p = ", solucion);
# Out:
# Introducir los valores de:
# a = ?
# 8
# b = ?
# 10
# c = ?
# 12
# d = ?
# 54
# x = ?
# 7
# La solución es p =  3372

# %% [markdown]
# Corrige los errores.
#
# Lee los mensajes de error e intenta corregirlos sobre el código. No te asustes porque haya tantos errores, a veces un error provoca en cascada otros errores. Corrige el primero que encuentres, vuelve a comprobar y repite hasta arreglarlo por completo.
#
# Errores que realmente había:
#
# ...
#
# a=int(input()) #Insertar los paréntesis a input
#
# ...
#
# print( "d = ? ") #Insertar paréntesis
#
# d=int(input()) #Insertar la función que transforme lo leído por teclado en un entero
#
# ...
#
# x=int(input()  #Insertar paréntesis

# %% [markdown]
# ###Segundo programa
# Con este ejercicio repasarás como:
# *   Editar un programa en Python
# *   Guardarlo
# *   Ejecutarlo
#
# Ejecuta y guarda la siguiente celda que contiene el programa escrito en Python.

# %%
"""
FECHA:
AUTOR: profesores de Informática
DESCRIPCIÓN:
Calcula el número de apariciones de una subcadena dentro de una cadena que se
pase por teclado.
Si no hay apariciones de la subcadena el programa devolverá 0.
ENTRADAS: la cadena principal sobre la que realizaremos la búsqueda y la cadena
que se quiere buscar
SALIDAS: el número de apariciones de la subcadena
ERRORES:

"""

contador = 0 #Inicializamos un contador a 0 para llevar la cuenta de las ocurrencias

# Pedimos al usuario que ingrese las cadenas
cadena = input("Ingrese la cadena principal: ")
subcadena = input("Ingrese la subcadena a buscar: ")

contador = cadena.count(subcadena) #la función count se ejecuta sobre cadena y
#cuenta el número de veces que aparece subcadenak

# Mostramos el resultado
print("La subcadena aparece", contador, "veces.")
# Out:
# Ingrese la cadena principal: Hola, bonita pala, la verdad. Lamento que tenga la audacia de enterrarla con ella.
# Ingrese la subcadena a buscar: la
# La subcadena aparece 6 veces.

# %% [markdown]
# ###Ejercicios
#
# 1.   Escribe un programa que dadas dos cadenas te muestre por pantalla el número de veces que aparece una cadena dentro de la otra.
# 2. Escribe un programa que dada una letra minúscula muestre por pantalla la correspondiente letra mayúscula.
#
#
# **Nota:** recuerda guardar el progreso del cuaderno en el repositorio de GitHub. Si no lo haces perderás todo el progreso.
